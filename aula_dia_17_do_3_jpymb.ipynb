# %% [markdown]
# <a href="https://colab.research.google.com/github/young-mota/programa-o-algoritimo/blob/main/aula_dia_17_do_3_jpymb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Operafores arítimeticos
# fazer um programa que calcula operações com 02 numeros

#entrada

a= int(input("digite um numero: "))
b= int(input("digite um numero: "))

#processmento

soma= a+b

#saida
print("")
print("-------------Operadores aritimeticos-----------")
print("")
print("--------------soma------------")
print("")
print(f"o resultado da soma de {a}mais {b} é igual a : {soma}")
print("----------------------------------------------------------------------")
# Out:
# digite um numero: 78
# digite um numero: 23
#
# -------------Operadores aritimeticos-----------
#
# --------------soma------------
#
# o resultado da soma de 78mais 23 é igual a : 101
# ----------------------------------------------------------------------

# %%
# Operafores arítimeticos
# fazer um programa que calcula operações com 02 numeros

#entrada

a= int(input("digite um numero: "))
b= int(input("digite um numero: "))

#processmento

subtração= a-b

#saida
print("")
print("-------------Operadores aritimeticos-----------")
print("")
print("--------------subtração------------")
print("")
print(f"o resultado da subtração de {a} menos {b} é igual a : {subtração}")
print("----------------------------------------------------------------------")
# Out:
# digite um numero: 5
# digite um numero: 3
#
# -------------Operadores aritimeticos-----------
#
# --------------subtração------------
#
# o resultado da subtração de 5 menos 3 é igual a : 2
# ----------------------------------------------------------------------

# %%
# Operafores arítimeticos
# fazer um programa que calcula operações com 02 numeros

#entrada

a= int(input("digite um numero: "))
b= int(input("digite um numero: "))

#processmento

divisão= a/b

#saida
print("")
print("-------------Operadores aritimeticos-----------")
print("")
print("--------------divisão------------")
print("")
print(f"o resultado da divisão de {a}dividido {b} é igual a : {divisão}")
print("----------------------------------------------------------------------")
# Out:
# digite um numero: 8
# digite um numero: 2
#
# -------------Operadores aritimeticos-----------
#
# --------------divisão------------
#
# o resultado da divisão de 8dividido 2 é igual a : 4.0
# ----------------------------------------------------------------------

# %%
# Operafores arítimeticos
# fazer um programa que calcula operações com 02 numeros

#entrada

a= int(input("digite um numero: "))
b= int(input("digite um numero: "))

#processmento

divisão= a*b

#saida
print("")
print("-------------Operadores aritimeticas-----------")
print("")
print("--------------mutiplicação------------")
print("")
print(f"o resultado da mutiplicação de {a} vezes {b} é igual a : {mutiplicação}")
print("----------------------------------------------------------------------")
# Out:
# digite um numero: 8
# digite um numero: 2
#
# -------------Operadores aritimeticos-----------
#
# --------------divisão------------
#
# o resultado da divisão de 8 dividido 2 é igual a : 16
# ----------------------------------------------------------------------

# %%
# operadores relacionais

# %%
# Operafores arítimeticos
# fazer um programa que calcula operações com 02 numeros

#entrada

a= int(input("digite um numero: "))
b= int(input("digite um numero: "))

#processamento

#comparação
igual= a == b

#saida

print(igual)
# Out:
# digite um numero: 8
# digite um numero: 2
#
# -------------Operadores aritimeticos-----------
#
# --------------divisão------------
#
# o resultado da divisão de 8 dividido 2 é igual a : 16
# ----------------------------------------------------------------------

# %%
# Operafores arítimeticos
# fazer um programa que calcula operações com 02 numeros

#entrada



#processamento

#comparação
diferente= a != b

#saida

print(diferente)
# Out:
# digite um numero:
# Entrada inválida. Por favor, digite um número inteiro.
# digite um numero: 8
# digite outro numero: 8
# False

# %%
# Operafores arítimeticos
# fazer um programa que calcula operações com 02 numeros

#entrada

a= int(input("digite um numero: "))
b= int(input("digite um numero: "))

#processamento

#comparação

diferente= a != b

#saida

print(diferente)
# Out:
# digite um numero: 1
# digite um numero: 1
# False

# %%
# Programa para converter temperatura de Celsius para Fahrenheit

# Entrada
while True:
    try:
        igite celsius = float(input("Da temperatura em Celsius: "))
        break
    except ValueError:
        print("Entrada inválida. Por favor, digite um número.")

# Processamento (F = (C * 9/5) + 32)
fahrenheit = (celsius * 9/5) + 32

# Saída
print(f"{celsius}°C é igual a {fahrenheit}°F")

# %%
# Operafores arítimeticos
# fazer um programa que calcula operações com 02 numeros

#entrada

a= int(input("digite um numero: "))
b= int(input("digite um numero: "))

#processamento

#comparação

maior= a>b
menor= a<b
maiorigual= a>=b
menorigual= a<=b

#saida

print(maior)
print(menor)
print(maiorigual)
print(menorigual)
# Out:
# digite um numero: 1
# digite um numero: 1
# False

# %%
#fazer um programa de converter a temperatura
# f = C × 9/5) + 32


#entrada
c=int(input(digite os numero de celciuos ))

#processamneto
f = c × 9/5) + 32

#saida
print(f"{c} graus celsius = {f} graus fahrenheit ")

# %%
#fazer um programa que converte km em metros
#entrada
km= int(input("digite a quantidade de km: "))

#processaneto
m= km*1000

#saida
print(f"{km}km = {m}m")
# Out:
# digite a quantidade de km: 4
# 4km = 4000m

# %%
#fazer um programa que converte horas em minutos
#entrada
h= int(input("digite a quantidade de horas: "))

#processaneto
m= h*60

#saida
print(f"{h}h = {m}m")
# Out:
# digite a quantidade de horas: 7
# 7h = 420m
