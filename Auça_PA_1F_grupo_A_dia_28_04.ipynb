# %% [markdown]
# <a href="https://colab.research.google.com/github/young-mota/programa-o-algoritimo/blob/main/Au%C3%A7a_PA_1F_grupo_A_dia_28_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#laços e iteração
print("hello world!")
# Out:
# hello world!

# %%
for i in range (7):
 print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
palavra = "python"
invertida = ""
for i in (palavra):
  invertida = i + invertida
  print (invertida)
# Out:
# p
# yp
# typ
# htyp
# ohtyp
# nohtyp

# %%
#escrever um programa que verifica se a palavra é palindroma e imprime a plavara

#entrada
int (input("digite sua palavra"))
invertida= ""
for i in (palavra):
 invertida = 1 + invertida
 if invertida == palavra:
  print (f"{palavra} é uma palavra palindroma")
  else:
  print (f"{palavra} não é uma palavra polindroma")

# %%
# escreva um programa que o usuario digita um numero e o programa imprime os numeros pares de 0 até o numero
# numeros pares

int float(input("digite seu numero"))
